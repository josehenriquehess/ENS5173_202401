# %% [markdown]
# # Aula 2 - Comandos básicos no Python - 03/04/2024
#
# Nesta aula aprenderemos a importar pacotes e os tipos de variáveis \
# Desenvolvedor: José Henrique Hess

# %% [markdown]
# ## Tipos de variáveis

# %%
# Criando variáveis inteiras
a = 1
print(type(a))
print('a = '+ str(a))
# Out:
# <class 'int'>
# a = 1

# %%
# Criando variáveis string
b='Vasco da '
c='Gama'
print(b+c)
print(type(b))
# Out:
# Vasco da Gama
# <class 'str'>

# %%
# Criando variáveis float/double precision
d = 666.666
print(d)
print(type(d))
# Out:
# 666.666
# <class 'float'>

# %%
# Variável inteira
a = 1
print('Valor de a = ' + str(a))
type(a)
# Out:
# Valor de a = 1
# int

# %%
# Variável dupla precisão
b = 1.0
print(b)
type(b)
# Out:
# 1.0
# float

# %%
# Converter float para int
c = int(b)
print(c)
type(c)
# Out:
# 1
# int

# %%
# Delacrando nan
import numpy as np
d = np.nan
print(d)
type(d)
# Out:
# nan
# float

# %%
# Operação com NaN
e = d*1
print(e)
e = d+1
print(e)
e = np.nansum([d,1])
print(e)
# Out:
# nan
# nan
# 1.0

# %% [markdown]
# ## Dados de texto

# %%
# Declaração de variável texto
f = 'Fábio'
g = 'Gabriel'
print(f)
print(g)
print(f+g)
print(f+' '+g)
# Out:
# Fábio
# Gabriel
# FábioGabriel
# Fábio Gabriel

# %% [markdown]
# ## Dados tipo bool - lógica

# %%
a == 1
# Out:
# True

# %%
h = (a==1)
print(h)
type(h)
# Out:
# True
# bool

# %%
i = True
type(i)
# Out:
# bool

# %%
ii = 'True'
type(ii)
# Out:
# str

# %% [markdown]
# ### Operação de comparação

# %%
# Operação ==
a==b
# Out:
# True

# %%
# Operação ><
a>b
# Out:
# False

# %%
# Operação !=
a!=b
# Out:
# False

# %%
# Operação >= ou <=
a>=b
# Out:
# True

# %% [markdown]
# ## Operações matemáticas

# %%
# Soma
a+b
# Out:
# 2.0

# %%
# Soma e atribui valor
ab = a+b
print(ab)
# Out:
# 2.0

# %%
# Multiplicação 
l = a*b # Não use l como variável
print("Não use l como nome de variável")
j = a*b
print(j)
# Out:
# Não use l como nome de variável
# 1.0

# %%
# Divisão
a/b
# Out:
# 1.0

# %%
## Potência
5**2
# Out:
# 25

# %%
# Operações matemáticas com a biblioteca math
import math

math.exp(10)
# Out:
# 22026.465794806718

# %%
math.exp(0)
# Out:
# 1.0

# %%
math.exp(a)
# Out:
# 2.718281828459045

# %%
math.exp(-10)
# Out:
# 4.5399929762484854e-05

# %%
import math as mt
mt.log(c)
# Out:
# 0.0

# %%
mt.log10(100)
# Out:
# 2.0

# %% [markdown]
# ## Listas

# %%
myFirstList = [1,2,3]
print(myFirstList)
# Out:
# [1, 2, 3]

# %%
# Acessando valores de lista pelo index
print(myFirstList[0])
print(myFirstList[2])
# Out:
# 1
# 3

# %%
myFirstList==a
# Out:
# False

# %%
myFirstList[0]==a
# Out:
# True

# %%
mySecList = [1,a,'c']
print(mySecList)
# Out:
# [1, 1, 'c']

# %%
type(mySecList)
# Out:
# list

# %%
type(mySecList[2])
# Out:
# str

# %%
type(mySecList[1])
# Out:
# int

# %% [markdown]
# ## Caminhos = path

# %%
path = r"C:\Users\joseh\Documents\GitHub\ENS5173_202401"
print(path)
# Out:
# C:\Users\joseh\Documents\GitHub\ENS5173_202401

# %%
path = "C:/Users/joseh/Documents/GitHub/ENS5173_202401"
print(path)
# Out:
# C:/Users/joseh/Documents/GitHub/ENS5173_202401

# %%
import os
# Listar arquivos na pasta
os.listdir(path)
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'Aula01.ipynb',
#  'inputs',
#  'pyEnv',
#  'README.md',
#  'scripts']

# %%
# Selecionar primeiro arquivo listado
os.listdir(path)[0]
# Out:
# '.git'

# %%
# Concatenando caminhos
path+"/"+os.listdir(path)[0]
# Out:
# 'C:/Users/joseh/Documents/GitHub/ENS5173_202401/.git'

# %%
# Listando caminho concatenado
os.listdir(path+"/"+os.listdir(path)[0])
# Out:
# ['COMMIT_EDITMSG',
#  'config',
#  'description',
#  'FETCH_HEAD',
#  'HEAD',
#  'hooks',
#  'index',
#  'info',
#  'logs',
#  'objects',
#  'packed-refs',
#  'refs']

# %%
# Diretório que estou trabalhando
os.getcwd()
# Out:
# 'C:\\Users\\joseh\\Documents\\GitHub\\ENS5173_202401'

# %%
# Mudo de diretório para o caminho
os.chdir('C:\\Users\\joseh\\Documents\\GitHub\\ENS5173_202401')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\joseh\\Documents\\GitHub\\ENS5173_202401'

# %%
# Criando diretório 
new_path = os.getcwd()+'/test'

if os.path.isdir(new_path):
    print('diretório já existe')
else:
    print('Criando diretório '+new_path)
    os.mkdir(new_path)
# Out:
# diretório já existe

# %%
# Criando diretório 
new_path = os.getcwd()+'/test2'

if os.path.isdir(new_path):
    print('diretório já existe')
    # Criando um arquivo de texto
    with open(new_path+"/copy.txt", "w") as file:
        file.write("Your text goes here")
else:
    print('Criando diretório '+new_path)
    os.mkdir(new_path)
    with open(new_path+"/copy.txt", "w") as file:
        file.write("Your text goes here")
# Out:
# diretório já existe

# %% [markdown]
# ## Numpy arrays e Pandas DataFrames

# %%
import numpy as np
# Criando uma variável numpy
n = np.array(0)
type(n)
# Out:
# numpy.ndarray

# %%
# Criando uma variável numpy a partir de uma lista
myThirdList=[1,2,3,10,20,55]
n = np.array(myThirdList)
print(n)
# Out:
# [ 1  2  3 10 20 55]

# %%
# Criando uma matriz de 10x10 de números aleatórios entre 0 e 1
n = np.random.rand(10,10)
print(n)
# Dimensões da matrix
print(n.shape)
# Out:
# [[0.34314409 0.39786046 0.34643234 0.7237682  0.4419997  0.01936548
#   0.2791145  0.21787045 0.52333696 0.2192795 ]
#  [0.8526907  0.15029314 0.37820937 0.42816918 0.54022107 0.21584165
#   0.89627149 0.55117957 0.55809868 0.27455712]
#  [0.19549702 0.11118675 0.81012877 0.81736458 0.37376426 0.14023268
#   0.20531945 0.67001188 0.21772727 0.47776708]
#  [0.71758412 0.17371308 0.19469171 0.96021386 0.68775221 0.48449879
#   0.0292438  0.98551608 0.77970888 0.66187173]
#  [0.3925447  0.23717063 0.19252086 0.25792671 0.12082825 0.19940359
#   0.45945491 0.0307575  0.66160804 0.63406967]
#  [0.01243334 0.1134948  0.03378814 0.52921921 0.4456268  0.62519988
#   0.16790483 0.96438983 0.20094959 0.61729809]
#  [0.50199062 0.42843429 0.21248181 0.88658984 0.09246664 0.48537861
#   0.47397161 0.53336347 0.37223656 0.83857715]
#  [0.75146566 0.06906021 0.59682803 0.79970043 0.61579732 0.79760179
#   0.18489242 0.02610771 0.28051404 0.22770955]
#  [0.74632636 0.82132199 0.78255164 0.00253854 0.91964574 0.60365429
#   0.25920424 0.94287077 0.97567807 0.82202962]
#  [0.37474076 0.09130484 0.14986943 0.99230141 0.80571867 0.75620989
#   0.43708166 0.58137009 0.51246461 0.50018789]]
# (10, 10)

# %%
# Acessando valores da matriz
n[0,:]
# Out:
# array([0.71722285, 0.84799499, 0.81265064, 0.02800285, 0.69295535,
#        0.09750718, 0.94259022, 0.89598816, 0.86162801, 0.91354442])

# %%
n[:,0]
# Out:
# array([0.71722285, 0.94487684, 0.84492433, 0.39118152, 0.61523253,
#        0.67046356, 0.90918051, 0.14154001, 0.45863369, 0.73240467])

# %%
n[:,1:5]
# Out:
# array([[0.39786046, 0.34643234, 0.7237682 , 0.4419997 ],
#        [0.15029314, 0.37820937, 0.42816918, 0.54022107],
#        [0.11118675, 0.81012877, 0.81736458, 0.37376426],
#        [0.17371308, 0.19469171, 0.96021386, 0.68775221],
#        [0.23717063, 0.19252086, 0.25792671, 0.12082825],
#        [0.1134948 , 0.03378814, 0.52921921, 0.4456268 ],
#        [0.42843429, 0.21248181, 0.88658984, 0.09246664],
#        [0.06906021, 0.59682803, 0.79970043, 0.61579732],
#        [0.82132199, 0.78255164, 0.00253854, 0.91964574],
#        [0.09130484, 0.14986943, 0.99230141, 0.80571867]])

# %%
n[0,1:5]
# Out:
# array([0.84799499, 0.81265064, 0.02800285, 0.69295535])

# %%
n[0,-1]
# Out:
# 0.9135444195271243

# %%
n[0,4:-1]
# Out:
# array([0.69295535, 0.09750718, 0.94259022, 0.89598816, 0.86162801])

# %%
n[0,4:]
# Out:
# array([0.69295535, 0.09750718, 0.94259022, 0.89598816, 0.86162801,
#        0.91354442])

# %%
an = np.log(n*5)
print(an)
# Out:
# [[ 1.27706923  1.44455736  1.40198394 -1.96601098  1.24264821 -0.71839138
#    1.55031427  1.49960984  1.46050627  1.51901463]
#  [ 1.55273722  1.52491285  1.12753854 -0.09133082  0.95537949  1.27099747
#    0.27496556  1.04111986  0.60040632 -0.04162063]
#  [ 1.44092971  1.01303119  0.50148108  0.72600182 -2.08439328 -0.75257363
#    1.58520748  0.39458124  0.7910251   1.31332038]
#  [ 0.67085434  0.60714102  1.00698379  0.7089695   1.58999743  0.27898656
#    1.46847271  0.90499405  1.07620776 -0.66829028]
#  [ 1.12368294  1.08808509 -0.4056906   0.9209588  -0.08384613  1.05412169
#    1.41907748 -2.81290272  0.61887416  1.06684278]
#  [ 1.20965198  1.03178403  1.53422814  0.45106133 -2.10236323 -0.16510992
#    0.86011752  0.94524124  1.26335394  0.90819453]
#  [ 1.51422629  1.06920966  1.58950467  1.01951381  1.10404213  0.7479357
#   -0.67997144  0.90978075  1.59774586  1.29581257]
#  [-0.34573496  1.4260972   1.5808999   0.37575507  1.26523332 -1.12296317
#    0.7640357   1.59013133  1.17065056 -0.97657772]
#  [ 0.82993447  0.01824557  0.45859987  1.26040286 -0.14579862  1.31664903
#    1.03024253  1.51586516  1.56354596  0.59730243]
#  [ 1.29801582 -0.5995384   1.40965905  1.369486    1.57771744  1.53547539
#    1.07080014 -0.25423698 -0.38499191  0.64858625]]

# %% [markdown]
# # Aula 3 - Python - 04/04/2024

# %% [markdown]
# ## 1.1 Numpy arrays

# %%
import numpy as np

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.37283559 0.38098507]
#  [0.3558646  0.49702852]
#  [0.67724731 0.44022871]
#  [0.34546579 0.87091243]
#  [0.23778382 0.44448053]
#  [0.14055387 0.36301537]
#  [0.09953847 0.94979868]
#  [0.16469204 0.50280846]
#  [0.37362799 0.69706727]
#  [0.24353148 0.51566535]]
# (10, 2)

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# Out:
# [[379.10722989 387.17521916]
#  [362.30595623 502.0582355 ]
#  [680.4748396  445.82642274]
#  [352.0111345  872.20330646]
#  [245.40598558 450.03572406]
#  [149.14833038 369.38521329]
#  [108.54308126 950.30069601]
#  [173.04512135 507.78037401]
#  [379.89171174 700.09660024]
#  [251.09616606 520.50869221]]

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.10723386 0.33132641 0.20105465 ... 0.28612899 0.40807728 0.08349237]
#  [0.64601192 0.57996913 0.42235248 ... 0.74091244 0.20878232 0.4547552 ]
#  [0.80022267 0.79490211 0.63470489 ... 0.62544819 0.28108698 0.34995328]
#  ...
#  [0.18953364 0.33848846 0.38335678 ... 0.80171264 0.21366956 0.74232349]
#  [0.61141186 0.799203   0.13382621 ... 0.07521764 0.65627964 0.24434351]
#  [0.77671273 0.38751092 0.41730157 ... 0.44551046 0.75665916 0.7732284 ]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1,"h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## PANDAS

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %%
# Mostrando um dataframe
df['datetime'] = dtime

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10]
# Out:
# 1    0.314009
# 2    0.262543
# 3    0.262419
# 4    0.323476
# 5    0.755493
# 6    0.972481
# 7    0.571234
# 8    0.448057
# 9    0.511272
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0]
# Out:
# datetime
# 2060-01-01 00:00:00   2060-01-01 00:00:00
# 2060-01-01 01:00:00   2060-01-01 01:00:00
# 2060-01-01 02:00:00   2060-01-01 02:00:00
# 2060-01-01 03:00:00   2060-01-01 03:00:00
# 2060-01-01 04:00:00   2060-01-01 04:00:00
#                               ...
# 2060-12-31 19:00:00   2060-12-31 19:00:00
# 2060-12-31 20:00:00   2060-12-31 20:00:00
# 2060-12-31 21:00:00   2060-12-31 21:00:00
# 2060-12-31 22:00:00   2060-12-31 22:00:00
# 2060-12-31 23:00:00   2060-12-31 23:00:00
# Name: datetime, Length: 8784, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.109918
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.314009
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.262543
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.262419
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.323476
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.003908
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.149688
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.411459
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.414201
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.128945
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.109918  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.314009  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.262543  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.262419  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.323476  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.003908  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.149688  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.411459  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.414201  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.128945  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.109918
# 2022-01-01 01:00:00   10.314006
# 2022-01-01 02:00:00   10.262533
# 2022-01-01 03:00:00   10.262397
# 2022-01-01 04:00:00   10.323438
# ...                         ...
# 2022-12-31 19:00:00    9.797916
# 2022-12-31 20:00:00    9.945095
# 2022-12-31 21:00:00   10.208262
# 2022-12-31 22:00:00   10.212394
# 2022-12-31 23:00:00    9.928524
#
# [8760 rows x 7 columns]

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\joseh\Documents\GitHub\ENS5173_202401\dados\brutos\noise_2022.csv')

# %%
# Criando uma função
def noiseCreation(path,year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por José
    """

    # Criando um dataframe
    df = pd.DataFrame()

    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))

    # Montando um dataframe
    df['datetime'] = dtime

    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])

    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day

    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])

    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'noise_'+str(year)+'.csv')

    return df

# %%
path = 'C:/Users/joseh/Documents/GitHub/ENS5173_202401/dados/brutos/'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.691931  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.092620  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.240597  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.672466  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.024026  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.462294  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.011091  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.578908  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.153080  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.287926  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.691931
# 2009-01-01 01:00:00   10.092617
# 2009-01-01 02:00:00   10.240587
# 2009-01-01 03:00:00   10.672444
# 2009-01-01 04:00:00   10.023987
# ...                         ...
# 2009-12-31 19:00:00   10.256302
# 2009-12-31 20:00:00    9.806499
# 2009-12-31 21:00:00   10.375711
# 2009-12-31 22:00:00    9.951273
# 2009-12-31 23:00:00   10.087505
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano >2030:
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData)

# %%
allDataDf
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.686407
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.750526
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.070965
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.828279
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.881216
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.789932
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.021453
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.365995
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.821788
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.802075
#
#        sazonal  timeSeries
# 0     1.000000   10.686407
# 1     1.000000   10.750523
# 2     0.999999   10.070956
# 3     0.999998   10.828258
# 4     0.999996   10.881178
# ...        ...         ...
# 8779  0.982630   10.616232
# 8780  0.982759    9.849039
# 8781  0.982887   10.194863
# 8782  0.983014   10.651933
# 8783  0.983142   10.633492
#
# [113976 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])

# %% [markdown]
# # Aula 4 - Análise de Séries Temporais - 04/04/2024

# %%
import pandas as pd

path = r'
